# %%
import pandas as pd
import scanpy as sc
import numpy as np
import anndata as ad

import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb
from sklearn import preprocessing as pp

# %%
data_folder = '/dss/dsshome1/lxc07/gobi009/data/'

# %%
path_human_healthy = data_folder + 'P21000/'
path_upr = data_folder + 'GSE114297/'
path_human_spikein_drug = data_folder + 'GSE142465_human/'

# %% [markdown]
# ### Load annotations

# %%
# Load annotation for human healthy
adata_hh = sc.read_h5ad(path_human_healthy + 'data_annotated.h5ad')

# %%
hh_samples = ['114_human_islets_R266_74_years', 'HI_24', 'HI_61', 'HI_63', 'Human_Islet']

# %%
# Load annotation for upr
adata_upr = sc.read_h5ad(path_upr + 'data_annotated.h5ad')

# %%
upr_samples = ['Donor_1', 'Donor_2', 'Donor_3', 'Donor_4', 'Donor_5', 'Donor_6', 'Donor_7', 'Donor_8', 'Donor_9', 'Donor_10', 'Donor_11', 'Donor_12']

# %%
# Load annotation for human spikein drug
adata_hsd = sc.read_h5ad(path_human_spikein_drug + 'data_annotated.h5ad')

# %%
hsd_samples = ['SRR10751484', 'SRR10751489', 'SRR10751497', 'SRR10751498', 'SRR10751499', 'SRR10751500', 'SRR10751501']

# %% [markdown]
# ### Concatenating and filtering the three data sets

# %%
# Concatenate the data sets
adata = ad.concat([adata_hh, adata_upr, adata_hsd])
del adata_hh
del adata_upr
del adata_hsd

# %%
ct_col = 'cell_type'

# %%
# Filter for healthy samples and beta cells
adata = adata[adata.obs['file'].isin(hh_samples + upr_samples + hsd_samples)]

# %%
# Load metadata for the project
metadata_hh = pd.read_excel('/dss/dsshome1/lxc07/gobi009/data/scRNA-seq_pancreas_metadata.xlsx',
             sheet_name='human_healthy')
metadata_upr = pd.read_excel('/dss/dsshome1/lxc07/gobi009/data/scRNA-seq_pancreas_metadata.xlsx',
             sheet_name='UPR')
metadata_hsd = pd.read_excel('/dss/dsshome1/lxc07/gobi009/data/scRNA-seq_pancreas_metadata.xlsx',
             sheet_name='human_spikein_drug')

# %%
# Filter out removed samples
metadata_hh = metadata_hh[metadata_hh['sample_name'].isin(hh_samples)]
metadata_upr = metadata_upr[metadata_upr['sample_name'].isin(upr_samples)]
metadata_hsd = metadata_hsd[metadata_hsd['sample_name'].isin(hsd_samples)]

# Subset data frames to required columns
metadata_hh = metadata_hh[['sample_name', 'sex', 'age']]
metadata_upr = metadata_upr[['sample_name', 'sex', 'age']]
metadata_hsd = metadata_hsd[['sample_name', 'sex', 'age']]

# Add study name to data frames
metadata_hh['study'] = ['human_healthy' for _ in range(metadata_hh.shape[0])]
metadata_upr['study'] = ['UPR' for _ in range(metadata_upr.shape[0])]
metadata_hsd['study'] = ['human_spikein_drug' for _ in range(metadata_hsd.shape[0])]

# Concatenate data frames
metadata = pd.concat([metadata_hh, metadata_upr, metadata_hsd])

# %%
# capture removes warning from anndata
# Add age, sex and study to adata.obs (renaming just for the looks)
adata.obs.rename(columns={'file': 'sample_name'}, inplace=True)
merged_obs = pd.merge(adata.obs, metadata, on='sample_name')
merged_obs.index = adata.obs.index
adata.obs = merged_obs

# %%
# Remove the y from the age column
adata.obs['age'] = adata.obs['age'].map(lambda a: a.split(' ')[0])

# %%
adata.shape
# Out:
# (90374, 14977)

# %%
adata.obs
# Out:
#                                 sample_name  n_counts  n_genes   mt_frac  \
# index
# AAACCTGAGACAAAGG-1-HI_24              HI_24   19372.0     3136  0.092350
# AAACCTGAGACACGAC-1-HI_24              HI_24   13690.0     3347  0.047480
# AAACCTGAGTCCGGTC-1-HI_24              HI_24   12112.0     3197  0.051354
# AAACCTGCACTTAACG-1-HI_24              HI_24   11681.0     3120  0.055303
# AAACCTGGTACGACCC-1-HI_24              HI_24   23595.0     4477  0.116253
# ...                                     ...       ...      ...       ...
# TTTGTCACATCGTCGG-1-SRR10751498  SRR10751498    4153.0     1299  0.025765
# TTTGTCAGTAAGAGGA-1-SRR10751498  SRR10751498    3708.0     1237  0.044229
# TTTGTCAGTCTCTTAT-1-SRR10751498  SRR10751498    2489.0     1258  0.033347
# TTTGTCAGTTCTGGTA-1-SRR10751498  SRR10751498    6260.0     1777  0.030671
# TTTGTCATCGCTTAGA-1-SRR10751498  SRR10751498    4926.0     1767  0.018270
#
#                                n_counts_filter n_genes_filter mt_frac_filter  \
# index
# AAACCTGAGACAAAGG-1-HI_24                    ok             ok             ok
# AAACCTGAGACACGAC-1-HI_24                    ok             ok             ok
# AAACCTGAGTCCGGTC-1-HI_24                    ok             ok             ok
# AAACCTGCACTTAACG-1-HI_24                    ok             ok             ok
# AAACCTGGTACGACCC-1-HI_24                    ok             ok             ok
# ...                                        ...            ...            ...
# TTTGTCACATCGTCGG-1-SRR10751498              ok             ok             ok
# TTTGTCAGTAAGAGGA-1-SRR10751498              ok             ok             ok
# TTTGTCAGTCTCTTAT-1-SRR10751498              ok             ok             ok
# TTTGTCAGTTCTGGTA-1-SRR10751498              ok             ok             ok
# TTTGTCATCGCTTAGA-1-SRR10751498              ok             ok             ok
#
#                                 doublet_score  doublet doublet_score_filter  \
# index
# AAACCTGAGACAAAGG-1-HI_24             0.026517        0                   ok
# AAACCTGAGACACGAC-1-HI_24             0.028359        0                   ok
# AAACCTGAGTCCGGTC-1-HI_24             0.055249        0                   ok
# AAACCTGCACTTAACG-1-HI_24             0.007178        0                   ok
# AAACCTGGTACGACCC-1-HI_24             0.023177        0                   ok
# ...                                       ...      ...                  ...
# TTTGTCACATCGTCGG-1-SRR10751498       0.070423        0                   ok
# TTTGTCAGTAAGAGGA-1-SRR10751498       0.056652        0                   ok
# TTTGTCAGTCTCTTAT-1-SRR10751498       0.010193        0                   ok
# TTTGTCAGTTCTGGTA-1-SRR10751498       0.065355        0                   ok
# TTTGTCATCGCTTAGA-1-SRR10751498       0.023399        0                   ok
#
#                                 size_factors leiden cell_type cluster  \
# index
# AAACCTGAGACAAAGG-1-HI_24            1.016746     11      beta      17
# AAACCTGAGACACGAC-1-HI_24            1.004483      3     alpha       4
# AAACCTGAGTCCGGTC-1-HI_24            0.946407      3     alpha       4
# AAACCTGCACTTAACG-1-HI_24            0.890676      6     delta      12
# AAACCTGGTACGACCC-1-HI_24            1.757859      1      beta       6
# ...                                      ...    ...       ...     ...
# TTTGTCACATCGTCGG-1-SRR10751498      0.523244      0     alpha       0
# TTTGTCAGTAAGAGGA-1-SRR10751498      0.446222      0     alpha       0
# TTTGTCAGTCTCTTAT-1-SRR10751498      0.468760      2    ductal       2
# TTTGTCAGTTCTGGTA-1-SRR10751498      0.736444      0     alpha       0
# TTTGTCATCGCTTAGA-1-SRR10751498      0.816462      7    immune       6
#
#                                cell_type_multiplet     sex age  \
# index
# AAACCTGAGACAAAGG-1-HI_24                      beta  female  24
# AAACCTGAGACACGAC-1-HI_24                     alpha  female  24
# AAACCTGAGTCCGGTC-1-HI_24                     alpha  female  24
# AAACCTGCACTTAACG-1-HI_24                     delta  female  24
# AAACCTGGTACGACCC-1-HI_24                      beta  female  24
# ...                                            ...     ...  ..
# TTTGTCACATCGTCGG-1-SRR10751498               alpha    male  37
# TTTGTCAGTAAGAGGA-1-SRR10751498               alpha    male  37
# TTTGTCAGTCTCTTAT-1-SRR10751498              ductal    male  37
# TTTGTCAGTTCTGGTA-1-SRR10751498               alpha    male  37
# TTTGTCATCGCTTAGA-1-SRR10751498              immune    male  37
#
#                                              study
# index
# AAACCTGAGACAAAGG-1-HI_24             human_healthy
# AAACCTGAGACACGAC-1-HI_24             human_healthy
# AAACCTGAGTCCGGTC-1-HI_24             human_healthy
# AAACCTGCACTTAACG-1-HI_24             human_healthy
# AAACCTGGTACGACCC-1-HI_24             human_healthy
# ...                                            ...
# TTTGTCACATCGTCGG-1-SRR10751498  human_spikein_drug
# TTTGTCAGTAAGAGGA-1-SRR10751498  human_spikein_drug
# TTTGTCAGTCTCTTAT-1-SRR10751498  human_spikein_drug
# TTTGTCAGTTCTGGTA-1-SRR10751498  human_spikein_drug
# TTTGTCATCGCTTAGA-1-SRR10751498  human_spikein_drug
#
# [90374 rows x 18 columns]

# %% [raw]
# for sample in adata.obs['sample_name'].unique():
#     adata_sample = adata[adata.obs['sample_name'].isin([sample])]

# %%
genes = ['DEFB4A']
score_name = 'defb4a'

# %%
# Compute score
sc.tl.score_genes(adata, gene_list=genes, score_name=score_name + '_score', use_raw=False)
# Out:
# /dss/dsshome1/lxc07/gobi009/miniconda3/envs/block/lib/python3.8/site-packages/scanpy/tools/_score_genes.py:151: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):

# %%
scores = adata.obs[[score_name + '_score','sample_name']]
scores[score_name + '_score_norm'] = pp.minmax_scale(scores[score_name + '_score'])
rcParams['figure.figsize'] = (30, 30)
fig, axs = plt.subplots(3, 1)
plt.xticks(rotation = 90)
sb.violinplot(x='sample_name', y=score_name + '_score', data=scores, inner=None, ax=axs[0])
axs[0].title.set_text(score_name + ' scores (all celltypes)')
axs[0].grid()
sb.violinplot(x='sample_name', y=score_name + '_score_norm', data=scores, inner=None, ax=axs[1])
axs[1].title.set_text('Scaled ' + score_name + ' scores')
axs[1].grid()
sb.violinplot(x='sample_name', y=score_name + '_score_norm', data=scores[scores[score_name + '_score_norm'] > -10], inner=None, ax=axs[2])
axs[2].title.set_text('Scaled ' + score_name + 'score (with all cells)')
axs[2].grid()
# Out:
# /gpfs/scratch/pn25xo/gobi009/gobi009/ipykernel_31922/2457524397.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores[score_name + '_score_norm'] = pp.minmax_scale(scores[score_name + '_score'])

# %%
adata_beta = adata[adata.obs['cell_type'] == 'acinar'].copy()

# %%
# Compute score
sc.tl.score_genes(adata_beta, gene_list=genes, score_name=score_name + '_score', use_raw=False)
# Out:
# /dss/dsshome1/lxc07/gobi009/miniconda3/envs/block/lib/python3.8/site-packages/scanpy/tools/_score_genes.py:151: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):

# %%
scores = adata_beta.obs[[score_name + '_score','sample_name']]
scores[score_name + '_score_norm'] = pp.minmax_scale(scores[score_name + '_score'])
rcParams['figure.figsize'] = (30, 30)
fig, axs = plt.subplots(3, 1)
plt.xticks(rotation = 90)
sb.violinplot(x='sample_name', y=score_name + '_score', data=scores, inner=None, ax=axs[0])
axs[0].title.set_text(score_name + ' scores (only acinar cells)')
axs[0].grid()
sb.violinplot(x='sample_name', y=score_name + '_score_norm', data=scores, inner=None, ax=axs[1])
axs[1].title.set_text('Scaled ' + score_name + ' scores')
axs[1].grid()
sb.violinplot(x='sample_name', y=score_name + '_score_norm', data=scores[scores[score_name + '_score_norm'] > -10], inner=None, ax=axs[2])
axs[2].title.set_text('Scaled ' + score_name + 'scores (only beta cells)')
axs[2].grid()
# Out:
# /gpfs/scratch/pn25xo/gobi009/gobi009/ipykernel_31922/3699347419.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores[score_name + '_score_norm'] = pp.minmax_scale(scores[score_name + '_score'])

# %%
pd.DataFrame.equals(adata_beta.obs['defb4a_score'], adata.obs['defb4a_score'])
# Out:
# False

# %%
adata_beta.obs.shape
# Out:
# (3009, 19)

# %%
adata.obs.shape
# Out:
# (90374, 19)

# %%
adata.obs
# Out:
#                                 sample_name  n_counts  n_genes   mt_frac  \
# index
# AAACCTGAGACAAAGG-1-HI_24              HI_24   19372.0     3136  0.092350
# AAACCTGAGACACGAC-1-HI_24              HI_24   13690.0     3347  0.047480
# AAACCTGAGTCCGGTC-1-HI_24              HI_24   12112.0     3197  0.051354
# AAACCTGCACTTAACG-1-HI_24              HI_24   11681.0     3120  0.055303
# AAACCTGGTACGACCC-1-HI_24              HI_24   23595.0     4477  0.116253
# ...                                     ...       ...      ...       ...
# TTTGTCACATCGTCGG-1-SRR10751498  SRR10751498    4153.0     1299  0.025765
# TTTGTCAGTAAGAGGA-1-SRR10751498  SRR10751498    3708.0     1237  0.044229
# TTTGTCAGTCTCTTAT-1-SRR10751498  SRR10751498    2489.0     1258  0.033347
# TTTGTCAGTTCTGGTA-1-SRR10751498  SRR10751498    6260.0     1777  0.030671
# TTTGTCATCGCTTAGA-1-SRR10751498  SRR10751498    4926.0     1767  0.018270
#
#                                n_counts_filter n_genes_filter mt_frac_filter  \
# index
# AAACCTGAGACAAAGG-1-HI_24                    ok             ok             ok
# AAACCTGAGACACGAC-1-HI_24                    ok             ok             ok
# AAACCTGAGTCCGGTC-1-HI_24                    ok             ok             ok
# AAACCTGCACTTAACG-1-HI_24                    ok             ok             ok
# AAACCTGGTACGACCC-1-HI_24                    ok             ok             ok
# ...                                        ...            ...            ...
# TTTGTCACATCGTCGG-1-SRR10751498              ok             ok             ok
# TTTGTCAGTAAGAGGA-1-SRR10751498              ok             ok             ok
# TTTGTCAGTCTCTTAT-1-SRR10751498              ok             ok             ok
# TTTGTCAGTTCTGGTA-1-SRR10751498              ok             ok             ok
# TTTGTCATCGCTTAGA-1-SRR10751498              ok             ok             ok
#
#                                 doublet_score  doublet doublet_score_filter  \
# index
# AAACCTGAGACAAAGG-1-HI_24             0.026517        0                   ok
# AAACCTGAGACACGAC-1-HI_24             0.028359        0                   ok
# AAACCTGAGTCCGGTC-1-HI_24             0.055249        0                   ok
# AAACCTGCACTTAACG-1-HI_24             0.007178        0                   ok
# AAACCTGGTACGACCC-1-HI_24             0.023177        0                   ok
# ...                                       ...      ...                  ...
# TTTGTCACATCGTCGG-1-SRR10751498       0.070423        0                   ok
# TTTGTCAGTAAGAGGA-1-SRR10751498       0.056652        0                   ok
# TTTGTCAGTCTCTTAT-1-SRR10751498       0.010193        0                   ok
# TTTGTCAGTTCTGGTA-1-SRR10751498       0.065355        0                   ok
# TTTGTCATCGCTTAGA-1-SRR10751498       0.023399        0                   ok
#
#                                 size_factors leiden cell_type cluster  \
# index
# AAACCTGAGACAAAGG-1-HI_24            1.016746     11      beta      17
# AAACCTGAGACACGAC-1-HI_24            1.004483      3     alpha       4
# AAACCTGAGTCCGGTC-1-HI_24            0.946407      3     alpha       4
# AAACCTGCACTTAACG-1-HI_24            0.890676      6     delta      12
# AAACCTGGTACGACCC-1-HI_24            1.757859      1      beta       6
# ...                                      ...    ...       ...     ...
# TTTGTCACATCGTCGG-1-SRR10751498      0.523244      0     alpha       0
# TTTGTCAGTAAGAGGA-1-SRR10751498      0.446222      0     alpha       0
# TTTGTCAGTCTCTTAT-1-SRR10751498      0.468760      2    ductal       2
# TTTGTCAGTTCTGGTA-1-SRR10751498      0.736444      0     alpha       0
# TTTGTCATCGCTTAGA-1-SRR10751498      0.816462      7    immune       6
#
#                                cell_type_multiplet     sex age  \
# index
# AAACCTGAGACAAAGG-1-HI_24                      beta  female  24
# AAACCTGAGACACGAC-1-HI_24                     alpha  female  24
# AAACCTGAGTCCGGTC-1-HI_24                     alpha  female  24
# AAACCTGCACTTAACG-1-HI_24                     delta  female  24
# AAACCTGGTACGACCC-1-HI_24                      beta  female  24
# ...                                            ...     ...  ..
# TTTGTCACATCGTCGG-1-SRR10751498               alpha    male  37
# TTTGTCAGTAAGAGGA-1-SRR10751498               alpha    male  37
# TTTGTCAGTCTCTTAT-1-SRR10751498              ductal    male  37
# TTTGTCAGTTCTGGTA-1-SRR10751498               alpha    male  37
# TTTGTCATCGCTTAGA-1-SRR10751498              immune    male  37
#
#                                              study  defb4a_score
# index
# AAACCTGAGACAAAGG-1-HI_24             human_healthy     -0.013698
# AAACCTGAGACACGAC-1-HI_24             human_healthy     -0.041455
# AAACCTGAGTCCGGTC-1-HI_24             human_healthy     -0.014421
# AAACCTGCACTTAACG-1-HI_24             human_healthy     -0.015054
# AAACCTGGTACGACCC-1-HI_24             human_healthy     -0.027021
# ...                                            ...           ...
# TTTGTCACATCGTCGG-1-SRR10751498  human_spikein_drug      0.000000
# TTTGTCAGTAAGAGGA-1-SRR10751498  human_spikein_drug      0.000000
# TTTGTCAGTCTCTTAT-1-SRR10751498  human_spikein_drug      0.000000
# TTTGTCAGTTCTGGTA-1-SRR10751498  human_spikein_drug      0.000000
# TTTGTCATCGCTTAGA-1-SRR10751498  human_spikein_drug      0.000000
#
# [90374 rows x 19 columns]

# %%
sc.pp.neighbors(adata)
sc.tl.umap(adata)

# %%
rcParams['figure.figsize'] = (20, 20)
sc.pl.umap(adata, size=20, color=['defb4a_score', 'cell_type'])
